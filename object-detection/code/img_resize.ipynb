# %% [markdown]
# # 이미지 크기 줄이기

# %%
# !pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# ...

# %%
import cv2

# %%
import os,shutil
import glob
from PIL import Image
from pathlib import Path

#files = glob.glob('C:\\Users\\user\\labelImg\\data\\*.jpg')
files = glob.glob('C:\\Users\\user\\Downloads\\food_data\\Training\\TRAIN_007\\01016015\\*')

print(len(files))

cnt = 0
error_img=[]
for f in files:
    try:
        cnt += 1 
        img = cv2.imread(f)
        resize_img = cv2.resize(img, (0, 0), fx=0.8, fy=0.8, interpolation=cv2.INTER_AREA)
        cv2.imwrite(f, resize_img)
        if cnt%100 == 0:
            print(cnt)
    except:
        print(cnt, f)
        break
print('-fin-')
# Out:
# 1595
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# -fin-

# %%
import os,shutil
import glob
from PIL import Image
from pathlib import Path

#files = glob.glob('C:\\Users\\user\\labelImg\\data\\*.jpg')
files = glob.glob('C:\\Users\\user\\yolov5\\data\\test_datasets2\\val\\images\\*')


print(len(files))

cnt = 0
error_img=[]
for f in files:
    cnt += 1 
    img = cv2.imread(f)
    #print(f)
    #print(img.shape)
    resize_img = cv2.resize(img, (0, 0), fx=0.4, fy=0.4, interpolation=cv2.INTER_AREA)
    cv2.imwrite(f, resize_img)
    if cnt%100 == 0:
        print(cnt)
print('-fin-')
# Out:
# 41463
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# ...

# %%
#169
