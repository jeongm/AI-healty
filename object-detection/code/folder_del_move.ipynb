# %%
import os
import shutil

# %%
# 이미지 데이터셋 
db_path = "../db_food_name.txt"

with open(db_path,'r',encoding='UTF-8') as f:
    db_list = f.read().splitlines()

print(db_list,len(db_list))
# Out:
# ['꿩불고기', '닭갈비', '닭갈비', '닭꼬치', '더덕구이', '도미구이', '돼지갈비', '병어구이', '불고기', '붕장어소금구이', '소양념갈비구이', '양념왕갈비', '양념장어구이', '임연수구이', '짚불구이곰장어', '햄버그스테이크', '황태구이', '훈제오리', '게국지', '곰치국', '굴국밥', '김치국', '떡만둣국', '만둣국', '맑은감자국', '매생이국', '무된장국', '미소된장국', '바지락조개국', '뼈다귀해장국', '선지해장국', '소고기무국', '소고기미역국', '순대국', '시래기된장국', '올갱이국', '우거지해장국', '우렁된장국', '탕국', '홍합미역국', '황태해장국', '고추잡채', '난자완스', '도토리묵말이', '라조기', '물회', '생선물회', '소고기샤브샤브', '오징어순대', '초당순두부', '해파리냉채', '고들빼기', '열무얼갈이김치', '미나리나물', '취나물', '콩나물', '경단(깨)', '경단(콩)', '기피편', '녹두시루떡', '메밀전병', '무지개떡', '송편(깨)', '송편(콩)', '수수부꾸미', '수수팥떡', '시루떡', '쑥떡', '절편', '찹쌀떡', '간자장', '굴짬뽕', '기스면', '김치라면', '김치우동', '냉김치말이국수', '닭칼국수', '둘깨칼국수', '막국수', '삼선우동', '삼선자장면', '삼선짬뽕', '쌀국수', '열무김치국수', '열무냉면', '오일소스스파게티', '올갱이국수', '우동(일식)', '우동(중식)', '울면', '자장면', '짬뽕라면', '치즈라면', '크림소스스파게티', '토마토소스스파게티', '해물칼국수', '해물크림소스스파게티', '해물토마토소스스파게티', '골뱅이무침', '노각무침', '단무지무침', '달래나물무침', '더덕무침', '도토리묵', '밴댕이무침', '서대회무침', '쑥갓나물무침', '우거지나물무침', '쥐치채', '청포묵무침', '탕평채', '홍어무침', '고추장불고기 삼각김밥', '곤드레나물밥', '국밥', '농
# ...

# %%
path='../건강관리를 위한 음식 이미지/Training_images/'
dir_list=os.listdir(path)

print(dir_list)

cnt = 0
for dir in dir_list:
    if dir in db_list:
        print(dir + ' DB O')
        cnt+=1
    else:
        print(dir + ' DB X' + ' 삭제?')
        check= input()
        if check == 'y':
            shutil.rmtree(path +dir)
print(os.listdir(path), cnt)
# Out:
# ['blt샌드위치', '가츠동', '갈비구이', '갈비찜', '갈비탕', '감', '감자볶음', '감자샐러드', '감자튀김', '거봉포도', '게맛살', '고구마', '고등어구이', '고로케', '고르곤졸라피자', '곱창전골', '과일채소샐러드', '국수', '군만두', '귤', '김', '김밥', '김치국', '김치볶음밥', '김치찌개', '까르보나라', '깐풍기', '나가사끼짬뽕', '나시고랭', '냉면', '다시마', '다크초콜릿', '달걀말이', '달걀볶음밥', '달걀샌드위치', '달걀찜', '달걀후라이', '닭가슴살', '닭가슴살샐러드', '닭갈비', '닭강정', '닭찜', '당근케이크', '도넛', '돼지갈비찜', '돼지고기고추장불고기', '돼지고기볶음', '된장찌개', '두부', '딸기', '딸기라떼', '떡갈비', '떡만두국,고기만두', '떡볶이', '라떼', '라멘', '라면', '레모네이드', '롤케이크', '리조또', '리코타치즈', '마들렌', '마른오징어', '마카로니샐러드', '마카롱', '막걸리', '막대사탕', '만두', '만두국', '망고', '맥주', '머핀', '명란젓', '모듬초밥', '모듬튀김', '모듬회', '무김치', '물미역', '미소라멘', '미소장국', '미역국', '미역나물', '미트볼', '밀크초콜릿', '바게트빵', '바나나', '바나나우유', '바람떡', '밥', '방울토마토', '배추김치', '버섯', '버터', '버터쿠키', '베이글', '베이글샌드위치', '베이컨', '보드카', '보쌈', '복숭아', '볶음밥', '봉골레파스타', '부대찌개', '부침개', '북어국', '붕어빵', '브라우니', '브로콜리', '블랙커피', '블루베리', '비빔국수', '비빔냉면', '비빔밥', '비엔나소시지', '빵', '사과', '사과샐러드', '사과파이', '사이다', '사탕', '산딸기', '삶은달걀', '삼겹살구이', '삼계탕', '상추', '상추샐러드', '새싹샐러드', '새우', '새우구이', '새우볶
# ...

# %%
for i in db_list:
    if '샐러드' in i:
        print(i)
# Out:
# 샐러드김밥
# 퀴노아 치킨 샐러드
# 프레시 콘샐러드
# 콘샐러드
# 케이준치킨샐러드
# 홈샐러드(하절기)
# 홈샐러드(동절기)
# 4구 샐러드
# 콘샐러드
# 단호박+고구마샐러드
# 쉬림프 그릭 샐러드
# 쉬림프 콥 샐러드
# 아보카도 콥 샐러드
# 카프레제 샐러드
# 허브치킨 가든샐러드
# 그릴드치킨 시저샐러드
# 사이드 샐러드
# 스트로베리 시트론 샐러드
# 카프레제 발사믹 샐러드
# 리코타치즈올리브 샐러드
# 치킨듬뿍 보틀샐러드
# 동글동글 보틀 샐러드
# 나폴리샐러드
# 파파 가든 샐러드
# 콘샐러드
# 튜나 샐러드 샌드위치
# 로스트 비프 샐러드 밀 박스
# 로스트 치킨 샐러드 밀 박스
# 베이컨 포테이토 샐러드 밀 박스
# 브로콜리 에그 샐러드 밀 박스
# 쉬림프 코코넛 샐러드 밀 박스
# 콥 & 요거트 샐러드
# 단백질 듬뿍 로스트 치킨 샐러드 Mini
# 에그샐러드샌드위치
# 오리지널 시저 샐러드
# 오리지널 시저 샐러드 Mini
# 케이준치킨샐러드
# 과일컵샐러드
# 쉬림프콥샐러드
# 부드러운 마요 에그 샐러드
# 담백한 옥수수 감자 샐러드
# 베리&리코타치즈샐러드(M)
# 코코넛 쉬림프 샐러드
# 클래식 시저 샐러드
# 시저치킨 샐러드랩
# 케이준치킨 샐러드랩
# 콘샐러드
# 콘샐러드
# 햄&포테이토샐러드 샌드위치
# 햄치즈&에그샐러드샌드위치
# 베이컨 크랜베리치킨 샐러드
# 단호박 리코타 과일 샐러드
# 치킨시저샐러드
# 흔들어먹는 쉑쉑 타코 샐러드
# 흔들어먹는 쉑쉑 롤치즈 샐러드
# 리코타 & 상큼 과일 샐러드
# 치킨 텐더 샐러드
# 상큼과일치킨샐러드
# 콥 샐러드
# 감자샐러드
# 과일샐러드
# 단호박샐러드
# 닭가슴살샐러드
# 새싹채소샐러드
# 양배추샐러드
# 양상추샐러드
# 옥수수샐러드
# 참치샐러드
# 채소샐러드
# 완두콩과 당근을 넣은 감자요거트샐러드
# 마늘칩 감자샐러드
# 단호박견과류샐러드
# 치즈두부샐러드
# 코울슬로샐러드
# 연근샐러드 & 흑임자소스
# 이탈리안샐러드
# 치킨랜치샐러드
# 고구마 샐러드
# ...

# %%
path='../건강관리를 위한 음식 이미지/Training_images/'
dir_list=os.listdir(path)

print(dir_list,len(dir_list))
# Out:
# ['blt샌드위치', '가츠동', '갈비구이', '갈비찜', '갈비탕', '감', '감자볶음', '감자샐러드', '감자튀김', '거봉포도', '게맛살', '고구마', '고등어구이', '고로케', '고르곤졸라피자', '곱창전골', '과일채소샐러드', '국수', '군만두', '귤', '김', '김밥', '김치국', '김치볶음밥', '김치찌개', '까르보나라', '깐풍기', '나가사끼짬뽕', '나시고랭', '냉면', '다시마', '다크초콜릿', '달걀말이', '달걀볶음밥', '달걀샌드위치', '달걀찜', '달걀후라이', '닭가슴살', '닭가슴살샐러드', '닭갈비', '닭강정', '닭찜', '당근케이크', '도넛', '돼지갈비찜', '돼지고기고추장불고기', '돼지고기볶음', '된장찌개', '두부', '딸기', '딸기라떼', '떡갈비', '떡만두국,고기만두', '떡볶이', '라떼', '라멘', '라면', '레모네이드', '롤케이크', '리조또', '마들렌', '마른오징어', '마카로니샐러드', '마카롱', '막대사탕', '만두', '망고', '맥주', '머핀', '모듬튀김', '모듬회', '무김치', '미소장국', '미역국', '미트볼', '밀크초콜릿', '바나나', '바나나우유', '밥', '방울토마토', '배추김치', '버터', '버터쿠키', '베이글', '베이글샌드위치', '베이컨', '보쌈', '복숭아', '볶음밥', '봉골레파스타', '부대찌개', '부침개', '북어국', '붕어빵', '브라우니', '블루베리', '비빔국수', '비빔냉면', '비빔밥', '비엔나소시지', '빵', '사과', '사과샐러드', '사과파이', '사이다', '사탕', '삶은달걀', '삼겹살구이', '삼계탕', '상추', '상추샐러드', '새싹샐러드', '새우', '새우구이', '새우볶음밥', '새우튀김', '샌드위치', '생맥주', '생선구이', '생선회', '생크림', '생크림케이크', '소면', '소시지', '솜사탕', '쇠고기볶음', '수박', '숙주나물', '순대', '순대
# ...

# %%
path='../건강관리를 위한 음식 이미지/Training_labels/'
train_labels=os.listdir(path)

for dir in train_labels:
    if dir[:-5] not in dir_list:
        shutil.rmtree(path +dir)
print(os.listdir(path),len(os.listdir(path)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       4 for dir in train_labels:
#       5     if dir[:-5] not in dir_list:
# ----> 6         shutil.rmtree(path +dir)
#       7 print(os.listdir(path),len(os.listdir(path)))
#
# File C:\ProgramData\Anaconda3\lib\shutil.py:757, in rmtree(path, ignore_errors, onerror)
#     755     # can't continue even if onerror hook returns
#     756     return
# --> 757 return _rmtree_unsafe(path, onerror)
#
# File C:\ProgramData\Anaconda3\lib\shutil.py:625, in _rmtree_unsafe(path, onerror)
#     623 else:
#     624     try:
# --> 625         os.unlink(fullname)
#     626     except OSError:
#     627         onerror(os.unlink, fullname, sys.exc_info())
#
# KeyboardInterrupt:

# %%
path='../건강관리를 위한 음식 이미지/Validation_images/'
dir_list=os.listdir(path)
print(dir_list,len(dir_list))
# Out:
# ['blt샌드위치', '가츠동', '갈비구이', '갈비찜', '갈비탕', '감', '감자볶음', '감자샐러드', '감자튀김', '거봉포도', '게맛살', '고구마', '고등어구이', '고르곤졸라피자', '곱창전골', '과일채소샐러드', '국수', '군만두', '귤', '김', '김밥', '김치국', '김치볶음밥', '김치찌개', '까르보나라', '깐풍기', '나가사끼짬뽕', '나시고랭', '냉면', '다시마', '다크초콜릿', '달걀말이', '달걀볶음밥', '달걀샌드위치', '달걀찜', '달걀후라이', '닭가슴살', '닭가슴살샐러드', '닭갈비', '닭강정', '닭찜', '당근케이크', '도넛', '돼지갈비찜', '돼지고기고추장불고기', '돼지고기볶음', '된장찌개', '두부', '딸기', '딸기라떼', '떡갈비', '떡만두국,고기만두', '떡볶이', '라멘', '라면', '레모네이드', '롤케이크', '리조또', '마들렌', '마른오징어', '마카로니샐러드', '마카롱', '막대사탕', '만두', '망고', '맥주', '머핀', '모듬튀김', '모듬회', '무김치', '미소장국', '미역국', '미트볼', '바나나', '바나나우유', '밥', '방울토마토', '배추김치', '버터', '버터쿠키', '베이글', '베이글샌드위치', '베이컨', '보쌈', '복숭아', '볶음밥', '봉골레파스타', '부대찌개', '부침개', '북어국', '붕어빵', '브라우니', '블루베리', '비빔국수', '비빔냉면', '비빔밥', '비엔나소시지', '빵', '사과', '사과샐러드', '사과파이', '사이다', '사탕', '삶은달걀', '삼겹살구이', '삼계탕', '상추', '상추샐러드', '새싹샐러드', '새우', '새우구이', '새우볶음밥', '새우튀김', '샌드위치', '생맥주', '생선구이', '생선회', '생크림케이크', '소면', '소시지', '쇠고기볶음', '수박', '숙주나물', '순대', '순대국밥', '순대볶음', '순두부찌개', '순살찜닭', '순살치킨'
# ...

# %%
filePath = '../건강관리를 위한 음식 이미지/ImageClass.txt'
with open(filePath,'w',encoding='UTF-8') as f:
    for name in dir_list:
        f.write(name+'\n')

# %%
#vali

path='../건강관리를 위한 음식 이미지/Validation_labels/'
dir_list=os.listdir(path)

print(dir_list)

cnt = 0
for dir in dir_list:
    if dir in db_list:
        print(dir + ' DB O')
        cnt+=1
    else:
        print(dir + ' DB X' + ' 삭제?')
        check= input()
        if check == 'y':
            shutil.rmtree(path +dir)
print(os.listdir(path), cnt)

# %%
val_list[0][:-5]
# Out:
# 'blt샌드위치'

# %% [markdown]
# # 압축풀기

# %%
import zipfile, os

#압축풀기-> 한글안돔 십,.
path='../건강관리를 위한 음식 이미지/Training/'
train_labels=os.listdir(path)

for z in train_labels:
    zipfile.ZipFile(path+z).extractall(path)

# %% [markdown]
# # 파일 이동

# %% [markdown]
# import os, shutil
#
# src_path='../건강관리를 위한 음식 이미지/Training/'
# destination_path = '../건강관리를 위한 음식 이미지/Training_labels/'
#
# label_list = os.listdir(src_path)
#
# for folder in label_list:
#     json_list = os.listdir(src_path + folder)
#     print(json_list)
#     for json in json_list:
#         shutil.move(src_path + folder+ '/'+ json, destination_path)

# %%
# 이미지 폴더 이동

import os, shutil
from distutils.dir_util import copy_tree

src_path='../건강관리를 위한 음식 이미지/Training_images/'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_dataset\\train\\images\\'
 
img_folder = os.listdir(src_path) # 이미지 폴더들

for folder in img_folder:
    img_list = os.listdir(src_path+folder)
    for file in img_list:
        shutil.move(src_path+folder + '/'+file,move_path)

# %%
import os, shutil

print(len(os.listdir(move_path)))
# Out:
# 1256527

# %% [markdown]
# # 폐기

# %%
dir_list=os.listdir('../건강관리를 위한 음식 이미지/Training_images/')
val_list=os.listdir('../건강관리를 위한 음식 이미지/Training_labels/')

print(len(dir_list),len(val_list))

for dir in val_list:
    if dir[:-5] in dir_list:
        dir_list.remove(dir[:-5])
print(dir_list)
# Out:
# 293 262

# %%
label_list = os.listdir(destination_path)
print(len(label_list))
# Out:
# 2386173

# %% [markdown]
# # label image 맞추기

# %%
# 이미지 폴더 이동

import os,shutil

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images_1000\\'
label_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels\\'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels_1000\\'
 
img_list = os.listdir(img_path) # 이미지 폴더들
label_list = os.listdir(label_path)
print(len(img_list),len(label_list))

#dif = []

for name in label_list:
    if (name[:-4]+'.jpg') in img_list:
        shutil.move(label_path+'/'+name, move_path)
# Out:
# 202285 824858

# %%
len(os.listdir(move_path))
# Out:
# 202251

# %%
len(os.listdir(img_path))
# Out:
# 202251

# %% [markdown]
# img_list = os.listdir(img_path) # 이미지 폴더들
# label_list = os.listdir(move_path)
#
# print(len(img_list),len(label_list))
# for n in img_list:
#     if (n[:-4]+'.txt') not in label_list:
#         print(n)

# %%
food = img_list[0]
food_cnt = 0
class_cnt = 0
for file in img_list:
    food_cnt+=1
    if file[:7] != food[:7]:
        print(food, food_cnt)
        class_cnt += 1
        food_cnt = 0
        food = file
print(class_cnt)
# Out:
# A020103XX_00865.jpg 4863
# A020106XX_03368.jpg 6241
# A020107XX_01154.jpg 1189
# A020109XX_03789.jpg 5649
# A020114XX_04309.jpg 7071
# A020116XX_10216.jpg 2284
# A020117XX_04300.jpg 1036
# A020118XX_10921.jpg 9234
# A020120XX_00866.jpg 1778
# A020127XX_04391.jpg 6534
# A020129XX_00002.jpg 3820
# A020131XX_00865.jpg 2798
# A020133XX_00865.jpg 8374
# A020134XX_07488.jpg 436
# A020135XX_00590.jpg 4026
# A020139XX_00001.jpg 5888
# A020140XX_00870.jpg 6340
# A020142XX_00002.jpg 6164
# A020143XX_00001.jpg 5978
# A020144XX_00005.jpg 6874
# A020146XX_00001.jpg 11611
# A020148XX_06444.jpg 4012
# A020149XX_00865.jpg 6298
# A020151_50001.jpg 488
# A020157XX_02191.jpg 2385
# A020178XX_00001.jpg 5466
# A020506XX_10291.jpg 5515
# A020507XX_00001.jpg 6346
# A020509XX_10477.jpg 4340
# A020511XX_02567.jpg 6096
# A020515XX_00001.jpg 866
# A020518XX_00001.jpg 5920
# A020520XX_00001.jpg 892
# A020521XX_00001.jpg 4954
# A020523XX_00001.jpg 6533
# A020524XX_00001.jpg 6605
# A020530XX_00001.jpg 5121
# ...

# %%
print(img_list[0][:8])
# Out:
# A020103X

# %% [markdown]
# # 샌드위치 합체
# 샌드위치 : 116
# 4717 + 205햄치즈 + 184blt + 311달걀

# %%
import os,shutil

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images\\'
label_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels\\'
#move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\trash\\'
 
img_list = os.listdir(img_path) # 이미지 폴더들
label_list = os.listdir(label_path)

sand = ['A210105'] # 바꾸고 싶은 파일

for file in label_list:
    if file[:7] in sand:
        with open(label_path + '/' + file,'r') as f:
            value = f.read().split()

        print(value) # 

        value[0] = str('67') # 바꿀 라벨 번호
        
        print(value)
        # list txt파일로 저장
        with open(label_path + '/' + file,'w',encoding='UTF-8') as f:
            for v in value:
                f.write(v+' ')
# Out:
# ['117', '0.751259', '0.663444', '0.288000', '0.673111']
# ['67', '0.751259', '0.663444', '0.288000', '0.673111']
# ['117', '0.570063', '0.641667', '0.408437', '0.716667']
# ['67', '0.570063', '0.641667', '0.408437', '0.716667']
# ['117', '0.443931', '0.594969', '0.189196', '0.384258']
# ['67', '0.443931', '0.594969', '0.189196', '0.384258']
# ['117', '0.403810', '0.579476', '0.685798', '0.566359']
# ['67', '0.403810', '0.579476', '0.685798', '0.566359']
# ['117', '0.494214', '0.520833', '0.490739', '0.850311']
# ['67', '0.494214', '0.520833', '0.490739', '0.850311']
# ['117', '0.434941', '0.581087', '0.308096', '0.453705']
# ['67', '0.434941', '0.581087', '0.308096', '0.453705']
# ['117', '0.299381', '0.485339', '0.231481', '0.557100']
# ['67', '0.299381', '0.485339', '0.231481', '0.557100']
# ['117', '0.448191', '0.518508', '0.387730', '0.768522']
# ['67', '0.448191', '0.518508', '0.387730', '0.768522']
# ['117', '0.646680', '0.528712', '0.408396', '0.942576']
# ...

# %%
len(os.listdir(img_path))
# Out:
# 1085376

# %% [markdown]
# # 샐러드 삭제

# %%
import os,shutil

sel_d = ['B140713XX','B140720XX','B140729XX','B140731XX','B140732XX','B140737XX',
         'B140745XX','B140750XX','B140761XX','B140767XX','B140770XX','B140774XX']

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images\\'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\trash\\'
 
img_list = os.listdir(img_path)
print(len(img_list))

cnt = 1
for name in img_list:
    if (name[:9]) == 'B140774XX':
        cnt+=1
        if cnt > 1001:
            shutil.move(img_path+'/'+name, move_path)
print(cnt)
# Out:
# 1092871
# 8496

# %%
import os,shutil

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images\\'
label_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels\\'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\trash\\'
 
img_list = os.listdir(img_path) # 이미지 폴더들
with open('C:\\Users\\user\\yolov5\\data\\health_datasets\\del.txt','r',encoding='UTF-8') as f:
    del_list = f.read().splitlines()

print(del_list,len(del_list))


for name in img_list:
    if name in del_list:
        shutil.move(img_path+'/'+name, move_path)
# Out:
# ['A020157XX_02818.jpg', 'A020157XX_02819.jpg', 'A020157XX_02962.jpg', 'A020157XX_03007.jpg', 'A020157XX_03008.jpg', 'A020157XX_03031.jpg', 'A020157XX_03032.jpg', 'A020157XX_03044.jpg', 'A020157XX_03108.jpg', 'A020521XX_01519.jpg', 'A230104XX_19291.jpg', 'A230104XX_40959.jpg', 'A230116XX_01177.jpg', 'A230116XX_01178.jpg', 'A230116XX_01201.jpg', 'A230116XX_01239.jpg', 'A230116XX_01270.jpg', 'A230116XX_01278.jpg', 'A230116XX_01282.jpg', 'A230116XX_01296.jpg', 'A230116XX_01299.jpg', 'A230116XX_01319.jpg', 'A230116XX_01329.jpg', 'A230116XX_01476.jpg', 'A230116XX_01479.jpg', 'A230116XX_01495.jpg', 'A230116XX_01564.jpg', 'A230116XX_01568.jpg', 'A230116XX_01592.jpg', 'A230116XX_01593.jpg', 'A230116XX_01620.jpg', 'A230116XX_01696.jpg', 'A230116XX_01697.jpg', 'A230116XX_01702.jpg', 'A230116XX_01732.jpg', 'A230116XX_01736.jpg', 'A230116XX_01752.jpg', 'A230116XX_01753.jpg', 'A230116XX_01773.jpg', 'A230116XX_02017.jpg', 'A270406XX_11927.jpg', 'A270406XX_14739.jpg', 'B010316XX_02412.jpg', 'B050537
# ...

# %% [markdown]
# # 데이터 개수 줄이기 1000개로?

# %%
import os,shutil

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images\\'
label_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels\\'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images_1000\\'
 
img_list = os.listdir(img_path) # 이미지 폴더들
print(len(img_list))

img_num = []
point = img_list[0][:7]
cnt = 0
print(point)
for name in img_list:
    cnt +=1
    if name[:7] != point: # 
        img_num.append(name[:7])
        point = name[:7]
        cnt = 0
    if cnt < 1001:
        shutil.move(img_path+'/'+name, move_path)
# Out:
# 824892
# A020118

# %%
len(img_num)
# Out:
# 231

# %%
import os,shutil

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images\\'
label_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels\\'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\trash\\'
 
img_list = os.listdir(move_path) # 이미지 폴더들
print(len(img_list))

point = 'A020140XX'
cnt = 0
print(point)
for name in img_list:
    if name[:9] == point:
        cnt +=1
        shutil.move(move_path+'/'+name, img_path)
        print(name)
# Out:
# 202236
# A020140XX
# A020140XX_01470.jpg
# A020140XX_01470.txt
# A020140XX_01471.jpg
# A020140XX_01471.txt
# A020140XX_01476.jpg
# A020140XX_01476.txt
# A020140XX_01477.jpg
# A020140XX_01477.txt
# A020140XX_01481.jpg
# A020140XX_01481.txt
# A020140XX_01483.jpg
# A020140XX_01483.txt
# A020140XX_01484.jpg
# A020140XX_01484.txt
# A020140XX_01485.jpg
# A020140XX_01485.txt
# A020140XX_01487.jpg
# A020140XX_01487.txt
# A020140XX_01488.jpg
# A020140XX_01488.txt
# A020140XX_01491.jpg
# A020140XX_01491.txt
# A020140XX_01492.jpg
# A020140XX_01492.txt
# A020140XX_01493.jpg
# A020140XX_01493.txt
# A020140XX_01494.jpg
# A020140XX_01494.txt
# A020140XX_01500.jpg
# A020140XX_01500.txt
# A020140XX_01501.jpg
# A020140XX_01501.txt
# A020140XX_01502.jpg
# A020140XX_01502.txt
# A020140XX_01504.jpg
# A020140XX_01504.txt
# A020140XX_01505.jpg
# A020140XX_01505.txt
# A020140XX_01506.jpg
# A020140XX_01506.txt
# A020140XX_01507.jpg
# A020140XX_01507.txt
# A020140XX_01508.jpg
# A020140XX_01508.txt
# ...

# %% [markdown]
# # 폴더 내 전부 이동

# %%
import os,shutil

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images\\'
label_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels\\'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images_1000\\'
 
img_list = os.listdir(move_path) # 이미지 폴더들
for name in img_list:
    shutil.move(move_path+'/'+name, img_path)

# %%
len(os.listdir(img_path))
# Out:
# 824892

# %% [markdown]
# # class개수

# %%
import os,shutil

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images\\'
label_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels\\'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels_1000\\'
 
img_list = os.listdir(img_path) # 이미지 폴더들
label_list = os.listdir(label_path)
print(len(img_list),len(label_list))

food = img_list[0]
food_cnt = 0
class_cnt = 0
for file in label_list:
    food_cnt+=1
    if file[:7] != food[:7]:
        print(food, food_cnt)
        class_cnt += 1
        food_cnt = 0
        food = file
print(class_cnt)
# Out:
# 151324 150547
# A020118XX_10921.jpg 787
# A020120XX_00866.txt 785
# A020127XX_04391.txt 812
# A020131XX_00865.txt 794
# A020139XX_00001.txt 789
# A020140XX_00870.txt 418
# A020143XX_00003.txt 785
# A020144XX_00005.txt 816
# A020148XX_06444.txt 796
# A020149XX_00865.txt 786
# A020151_50001.txt 367
# A020178XX_00001.txt 797
# A020515XX_00001.txt 696
# A020523XX_00001.txt 798
# A020530XX_00001.txt 798
# A030117_50002.txt 258
# A190112_50001.txt 229
# A190113XX_00868.txt 811
# A190124XX_01704.txt 791
# A200113XX_06001.txt 807
# A200116XX_00001.txt 804
# A200117XX_00001.txt 813
# A200118XX_01231.txt 805
# A200119XX_00002.txt 796
# A200121XX_00001.txt 799
# A200329XX_00001.txt 782
# A200420XX_00608.txt 164
# A210103XX_06001.txt 807
# A210105XX_00001.txt 797
# A220117XX_06160.txt 550
# A220122XX_03389.txt 787
# A220126XX_00865.txt 795
# A220128XX_00865.txt 814
# A220132XX_00879.txt 801
# A220136XX_00865.txt 660
# A220138XX_00867.txt 788
# A220139XX_03080.txt 806
# A220170XX_02196.txt 787
# ...

# %% [markdown]
# # missmatch check

# %%
import os,shutil

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images\\'
label_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels\\'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels_1000\\'
 
img_list = os.listdir(img_path) # 이미지 폴더들
label_list = os.listdir(label_path)
print(len(img_list),len(label_list))

food = img_list[0]
food_cnt = 0
class_cnt = 0
for file in img_list:
    food_cnt+=1
    if file[:7] != food[:7]:
        print(food, food_cnt)
        class_cnt += 1
        food_cnt = 0
        food = file
print(class_cnt)
# Out:
# 150547 150547
# A020118XX_10921.jpg 787
# A020120XX_00866.jpg 785
# A020127XX_04391.jpg 812
# A020131XX_00865.jpg 794
# A020139XX_00001.jpg 789
# A020140XX_00870.jpg 418
# A020143XX_00003.jpg 785
# A020144XX_00005.jpg 816
# A020148XX_06444.jpg 796
# A020149XX_00865.jpg 786
# A020151_50001.jpg 367
# A020178XX_00001.jpg 797
# A020515XX_00001.jpg 696
# A020523XX_00001.jpg 798
# A020530XX_00001.jpg 798
# A030117_50002.jpg 258
# A190112_50001.jpg 229
# A190113XX_00868.jpg 811
# A190124XX_01704.jpg 791
# A200113XX_06001.jpg 807
# A200116XX_00001.jpg 804
# A200117XX_00001.jpg 813
# A200118XX_01231.jpg 805
# A200119XX_00002.jpg 796
# A200121XX_00001.jpg 799
# A200329XX_00001.jpg 782
# A200420XX_00608.jpg 164
# A210103XX_06001.jpg 807
# A210105XX_00001.jpg 797
# A220117XX_06160.jpg 550
# A220122XX_03389.jpg 787
# A220126XX_00865.jpg 795
# A220128XX_00865.jpg 814
# A220132XX_00879.jpg 801
# A220136XX_00865.jpg 660
# A220138XX_00867.jpg 788
# A220139XX_03080.jpg 806
# A220170XX_02196.jpg 787
# ...

# %%
import os,shutil

img_path='C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\images\\'
label_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels\\'
move_path = 'C:\\Users\\user\\yolov5\\data\\health_datasets\\train\\labels_1000\\'
 
img_list = os.listdir(img_path) # 이미지 폴더들
label_list = os.listdir(label_path)
print(len(img_list),len(label_list))

food_cnt = 0
# Out:
# 150546 150546

# %%
food_cnt = 0
for file in img_list:
    food = file[:-4]+'.txt'
    if food not in label_list:
        print(file)
    food_cnt+=1
    if food_cnt%1000 == 0:
        print(food_cnt)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000

# %%
for file in label_list:
    with open(label_path + '/' + file,'r') as f:
        value = f.read().split()
    if len(value) != 5:
        print(file, value)
