# %%
import pandas as pd
import xlrd

# %%
# 데이터 불러오기
path=''
df_origin = pd.read_excel("../건강관리를 위한 음식 이미지/Info Table/통합 식품영양성분DB/통합 식품영양성분DB.xlsx")

# %%
df = df_origin

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 225', 'Unnamed: 226', 'Unnamed: 227', 'Unnamed: 228',
#        'Unnamed: 229', 'Unnamed: 230', 'Unnamed: 231', 'Unnamed: 232',
#        'Unnamed: 233', 'Unnamed: 234'],
#       dtype='object', length=235)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52943 entries, 0 to 52942
# Columns: 235 entries, Unnamed: 0 to Unnamed: 234
# dtypes: object(235)
# memory usage: 94.9+ MB

# %%
# (행,열) 크기 확인
df.shape
# Out:
# (52943, 235)

# %%
# 인덱스 지정 행 삭제
df = df.drop([0,1],axis=0)

# %%
# 첫 번째 행을 column으로 지정
df = df.rename(columns=df.iloc[0])
df = df.drop(df.index[0])

# %%
df.head(5)
# Out:
#   NO       SAMPLE_ID     식품코드 DB군  상용제품   식품명    연도 지역 / 제조사 채취시기 식품대분류  ...  \
# 3  1  D000006-94-AVG  D000006  음식  품목대표  꿩불고기  2019       충주   평균   구이류  ...
# 4  2  D000007-ZZ-AVG  D000007  음식  품목대표   닭갈비  2019   전국(대표)   평균   구이류  ...
# 5  3  D000008-66-AVG  D000008  음식  품목대표   닭갈비  2019       춘천   평균   구이류  ...
# 6  4  D000009-ZZ-AVG  D000009  음식  품목대표   닭꼬치  2019   전국(대표)   평균   구이류  ...
# 7  5  D000010-ZZ-AVG  D000010  음식  품목대표  더덕구이  2019   전국(대표)   평균   구이류  ...
#
#   냉산가용성물질(㎎) 총 불포화지방산(g) 식염상당량(g)  회분(g) 폐기율(%) 가식부(%) 산가용성물질(%) 카페인(㎎)  \
# 3          -           -        -    5.8      -      -         -      -
# 4          -           -        -      7      -      -         -      -
# 5          -           -        -    4.5      -      -         -      -
# 6          -           -        -  1.218      -      -         -      -
# 7          -           -        -    2.5      -      -         -      -
#
#           성분표출처      발행기관
# 3  식약처('16) 제4권  식품의약품안전처
# 4  식약처('16) 제4권  식품의약품안전처
# 5  식약처('16) 제4권  식품의약품안전처
# 6  식약처('12) 제1권  식품의약품안전처
# 7  식약처('17) 제5권  식품의약품안전처
#
# [5 rows x 235 columns]

# %%
df.columns
# Out:
# Index(['NO', 'SAMPLE_ID', '식품코드', 'DB군', '상용제품', '식품명', '연도', '지역 / 제조사',
#        '채취시기', '식품대분류',
#        ...
#        '냉산가용성물질(㎎)', '총 불포화지방산(g)', '식염상당량(g)', '회분(g)', '폐기율(%)', '가식부(%)',
#        '산가용성물질(%)', '카페인(㎎)', '성분표출처', '발행기관'],
#       dtype='object', length=235)

# %%
# 열 삭제
#df.drop(['발행기관','성분표출처','연도'],axis=1)

# %%
# 특정 열 추출
df_class = df[['DB군','식품명','식품대분류','식품상세분류','에너지(㎉)','단백질(g)','지방(g)','탄수화물(g)','총 식이섬유(g)','콜레스테롤(㎎)']]

# %%
#df_class.head()
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52940 entries, 3 to 52942
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DB군        52940 non-null  object
#  1   식품명        52940 non-null  object
#  2   식품대분류      52940 non-null  object
#  3   식품상세분류     52940 non-null  object
#  4   에너지(㎉)     52940 non-null  object
#  5   단백질(g)     52940 non-null  object
#  6   지방(g)      52940 non-null  object
#  7   탄수화물(g)    52940 non-null  object
#  8   총 식이섬유(g)  52940 non-null  object
#  9   콜레스테롤(㎎)   52940 non-null  object
# dtypes: object(10)
# memory usage: 4.0+ MB

# %%
df_class[df_class['식품대분류']=='빵류'].head(30)
# Out:
#     DB군                     식품명 식품대분류           식품상세분류   에너지(㎉) 단백질(g)  \
# 165  음식                     곰보빵    빵류            기타 빵류  277.336  6.313
# 166  음식                      만주    빵류             앙금빵류  222.494   5.13
# 167  음식                   버터크림빵    빵류             크림빵류  229.957  4.905
# 168  음식                   불고기피자    빵류              피자류      505   27.4
# 169  음식                  참치샌드위치    빵류            샌드위치류      555   23.3
# 170  음식                   찹쌀도우넛    빵류  튀김빵류(도넛, 꽈배기 등)  207.047  3.526
# 171  음식                   채소고로케    빵류  튀김빵류(도넛, 꽈배기 등)  300.653  7.125
# 172  음식                  초콜릿케이크    빵류             케이크류  420.243  5.315
# 173  음식                   치즈케이크    빵류             케이크류  329.145  7.225
# 174  음식                    치즈피자    빵류              피자류      553   31.4
# 175  음식                  페이스트리빵    빵류           페이스트리류   319.59  5.992
# 176  음식                  페퍼로니피자    빵류              피자류      532   29.4
# 177  음식                  포테이토피자    빵류              피자류      628     28
# 294  음식         글램핑 바비큐(오리지널 L)    빵류              피자류      410     17
# 295  음식           글램핑 바비큐(나폴리M)    빵류              피자류      328     15
# 296  음식           글램핑 바비큐(나폴리L)    빵류              피자류      312     16
# 297  음식            글램핑 바비큐(씬 M)    빵류              피자류      266     13
# 298  음식            글램핑 바비큐(씬 L)    빵류              피자류      273     13
# 299  음식    글램핑 바비큐(슈퍼시드 함유 도우M)    빵류              피자류      485     24
# 300  음식    글램핑 바비큐(슈퍼시드 함유 도우L)    빵류              피자류      392     19
# 301  음식  글램핑 바비큐 더블치즈엣지(오리지널 M)    빵류              피자류      330     16
# 302  음식  글램핑 바비큐 더블치즈엣지(오리지널 L)    빵류              피자류      489     25
# 303  음식  더블크러스트 이베리코(더블 크러스트 L)    빵류              피자류      387     19
# 304  음식  더블크러스트 이베리코(더블 크러스트 M)    빵류              피자류      345     12
# 305  음식           리얼불고기(오리지널 L)    빵류              피자류      420     14
# 306  음식           리얼불고기(오리지널 M)    빵류              피자류      280     13
# 307  음식             리얼불고기(나폴리L)    빵류              피자류      334     16
# 308  음식             리얼불고기(나폴리M)    빵류              피자류      430     23
# 309  음식              리얼불고기(씬 L)    빵류              피자류      365     20
# 310  음식              리얼불고기(씬 M)    빵류              피자류      396     22
#
#       지방(g) 탄수화물(g) 총 식이섬유(g) 콜레스테롤(㎎)
# 165   9.273  42.157     2.854   23.592
# 166    1.64  46.803     3.402   15.674
# 167  11.043  27.736     1.584   17.814
# 168    16.7    61.2       4.9     45.7
# 169    35.1    36.5       5.3    57.86
# 170   3.682  39.952     2.047    1.156
# 171  16.378  31.187      1.11   41.895
# 172  24.955  43.597      2.43   50.839
# 173  20.632  28.638     1.243  126.775
# 174    15.8    71.2       6.3    48.04
# 175  18.396  32.516     2.126   16.946
# 176    14.8    70.3       5.5    41.73
# 177    25.5    71.6       6.8    48.95
# 294       -       -         -        -
# 295       -       -         -        -
# 296       -       -         -        -
# 297       -       -         -        -
# 298       -       -         -        -
# 299       -       -         -        -
# 300       -       -         -        -
# 301       -       -         -        -
# 302       -       -         -        -
# 303       -       -         -        -
# 304       -       -         -        -
# 305       -       -         -        -
# 306       -       -         -        -
# 307       -       -         -        -
# 308       -       -         -        -
# 309       -       -         -        -
# 310       -       -         -        -

# %%
df_class['식품대분류']
# Out:
# 3        구이류
# 4        구이류
# 5        구이류
# 6        구이류
# 7        구이류
#         ...
# 52938    캔디류
# 52939    캔디류
# 52940    캔디류
# 52941    캔디류
# 52942    캔디류
# Name: 식품대분류, Length: 52940, dtype: object
