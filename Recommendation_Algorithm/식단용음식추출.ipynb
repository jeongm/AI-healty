# %%
import pandas as pd

# %%
df = pd.read_excel("통합 식품영양성분DB_필요성분추출.xlsx",index_col='Unnamed: 0')
df.columns = df.iloc[2]
df = df[3:]

# %%
df.head()
# Out:
# NO   식품명 식품대분류 식품상세분류 1회제공량 내용량_단위   에너지(㎉)   수분(g)  단백질(g)  지방(g) 탄수화물(g)  \
# 1   꿩불고기   구이류   육류구이   500      g    368.8   412.6    33.5    8.5    39.7
# 2    닭갈비   구이류   육류구이   400      g   595.61   276.4    45.9   25.8    44.9
# 3    닭갈비   구이류   육류구이   300      g   558.47   195.4    45.5   31.6    23.1
# 4    닭꼬치   구이류   육류구이    70      g  176.723  35.308  11.562  8.565  13.348
# 5   더덕구이   구이류  채소류구이   100      g      184    58.1     3.1    5.2    31.1
#
# NO 총당류(g) 총 식이섬유(g)   나트륨(㎎) 아연(㎎) 비타민 B1(㎎) 비타민 B2(㎎) 비타민 B12(㎍) 비타민 C(㎎)  \
# 1    16.9       9.8  1264.31  3.99         0      0.33          0     2.99
# 2    21.2      11.6  1535.83  3.55      0.24      0.37       1.12     5.54
# 3     8.5       6.6  1016.94  3.59      0.22      0.38          0        0
# 4   3.152     2.072  286.911     0     0.226     0.184          0        0
# 5    11.6       6.8   743.37  0.59      0.23      0.08          0     1.34
#
# NO 콜레스테롤(㎎) 총 포화 지방산(g)
# 1    106.18         1.9
# ...

# %%
df['식품대분류'].value_counts()
# Out:
# 빵류         7771
# 과자         6808
# 즉석조리식품     4787
# 농축산물       3088
# 음료 및 차류    2493
#            ...
# 산양유           1
# 과실주           1
# 탈지농축우유        1
# 고춧가루          1
# 유산균첨가우유       1
# Name: 식품대분류, Length: 179, dtype: int64

# %%
df['식품상세분류'].value_counts()
# Out:
# 즉석조리식품           4767
# 빵류               3599
# 과자               3353
# 즉석섭취식품           1679
# 피자류              1457
#                  ...
# 과일파이필링              1
# 가공유크림               1
# 선천성 대사질환자용 식품       1
# 과실주                 1
# 유산균첨가우유             1
# Name: 식품상세분류, Length: 299, dtype: int64

# %%
df
# Out:
# NO               식품명 식품대분류 식품상세분류 1회제공량 내용량_단위   에너지(㎉)   수분(g)  단백질(g)  \
# 1               꿩불고기   구이류   육류구이   500      g    368.8   412.6    33.5
# 2                닭갈비   구이류   육류구이   400      g   595.61   276.4    45.9
# 4                닭꼬치   구이류   육류구이    70      g  176.723  35.308  11.562
# 5               더덕구이   구이류  채소류구이   100      g      184    58.1     3.1
# 6               도미구이   구이류  어패류구이   250      g      397   163.3    61.1
# ...              ...   ...    ...   ...    ...      ...     ...     ...
# 52934         빅쪼니복숭아   캔디류    캔디류    15      g       65       -       0
# 52935       블루하와이 젤리   캔디류    캔디류    42      g      156       -       3
# 52936       라임모히또 젤리   캔디류    캔디류    70      g      264       -       5
# 52937       꼬마쮸 복숭아맛   캔디류    캔디류    40      g      175       -       0
# 52940  It's 무설탕 레몬캔디   캔디류    캔디류    40      g      100       -       0
#
# NO     지방(g) 탄수화물(g)  ...     인(㎎)    칼륨(㎎)   나트륨(㎎) 아연(㎎) 비타민 B1(㎎)  \
# ...

# %%
df.drop_duplicates(['식품명'],inplace=True)

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
# NO               식품명 식품대분류 식품상세분류 1회제공량 내용량_단위   에너지(㎉)   수분(g)  단백질(g)  \
# 0               꿩불고기   구이류   육류구이   500      g    368.8   412.6    33.5
# 1                닭갈비   구이류   육류구이   400      g   595.61   276.4    45.9
# 2                닭꼬치   구이류   육류구이    70      g  176.723  35.308  11.562
# 3               더덕구이   구이류  채소류구이   100      g      184    58.1     3.1
# 4               도미구이   구이류  어패류구이   250      g      397   163.3    61.1
# ...              ...   ...    ...   ...    ...      ...     ...     ...
# 44466         빅쪼니복숭아   캔디류    캔디류    15      g       65       -       0
# 44467       블루하와이 젤리   캔디류    캔디류    42      g      156       -       3
# 44468       라임모히또 젤리   캔디류    캔디류    70      g      264       -       5
# 44469       꼬마쮸 복숭아맛   캔디류    캔디류    40      g      175       -       0
# 44470  It's 무설탕 레몬캔디   캔디류    캔디류    40      g      100       -       0
#
# NO     지방(g) 탄수화물(g)  ...     인(㎎)    칼륨(㎎)   나트륨(㎎) 아연(㎎) 비타민 B1(㎎)  \
# ...

# %%
(df['식품대분류'].value_counts() < 5)
# Out:
# 빵류         False
# 과자         False
# 즉석조리식품     False
# 농축산물       False
# 음료 및 차류    False
#            ...
# 산양유         True
# 과실주         True
# 탈지농축우유      True
# 고춧가루        True
# 유산균첨가우유     True
# Name: 식품대분류, Length: 179, dtype: bool

# %%
df['식품대분류'].value_counts()
# Out:
# 빵류         7771
# 과자         6808
# 즉석조리식품     4787
# 농축산물       3088
# 음료 및 차류    2493
#            ...
# 산양유           1
# 과실주           1
# 탈지농축우유        1
# 고춧가루          1
# 유산균첨가우유       1
# Name: 식품대분류, Length: 179, dtype: int64

# %%
df['식품대분류'].unique()
# Out:
# array(['구이류', '국 및 탕류', '볶음류', '기타', '튀김류', '회류', '찌개 및 전골류', '찜류',
#        '생채및 무침류', '김치류', '숙채류', '곡류 및 서류', '면 및 만두류', '밥류', '빵류',
#        '음료 및 차류', '장아찌 및 절임류', '전.적 및 부침류', '조림류', '죽 및 스프류', '포류', '과자류',
#        '아이스크림류', '젓갈류', '농축산물', '수산물', '과자', '과/채주스', '탄산음료', '과/채음료',
#        '인삼/홍삼음료', '혼합음료', '음료베이스', '건면', '생면', '기타발효음료', '가공두유', '유산균음료',
#        '캔디류', '환자용 식품', '숙면', '커피', '기타가공품', '유탕면', '초콜릿가공품', '즉석섭취식품',
#        '빙과', '탄산수', '추잉껌', '소시지', '햄', '프레스햄', '만두피', '발효소시지', '농후발효유',
#        '가공유', '강화우유', '가공치즈', '만두', '식육추출가공품', '양념육', '분쇄가공육제품', '액상차',
#        '참기름', '콩기름(대두유)', '기타식물성유지', '고형차', '잼', '즉석조리식품', '영/유아용 이유식',
#        '소스', '곡류가공품', '마요네즈', '카레(커리)', '가공버터', '밀크초콜릿', '어육소시지', '초콜릿',
#        '두부', '복합조미식품', '가공두부', '기타 수산물가공품', '자연치즈', '들기름', '발효유', '우유',
#        '향미유', '당절임', '두류가공품', '떡류', '물엿', '서류가공품', '준초콜릿', '체중조절용 조제식품',
#        '아이스크림', '알가열제품', '아이스밀크', '설탕', '기타설탕', '해바라기유', '올리브유', '어묵',
# ...

# %%
df['식품상세분류'].unique()
# Out:
# array(['육류구이', '채소류구이', '어패류구이', '어패류국.탕', '채소류국.탕', '기타 국 및 탕류', '육류국.탕',
#        '기타 볶음류', '육류볶음', '기타', '육류튀김', '회류', '육류찌개.전골', '어패류찜', '어패류무침',
#        '김치', '나물.숙채류', '떡류', '곡류 및 서류', '중식면류', '라면류', '국수류', '스파게티류',
#        '나물.채소류무침', '기타 생채.무침류', '김밥(초밥)류', '기타 밥류', '덮밥류', '비빔밥류', '볶음밥류',
#        '쌀밥.잡곡밥류', '채소류볶음', '어패류볶음', '기타 빵류', '앙금빵류', '크림빵류', '피자류',
#        '샌드위치류', '튀김빵류(도넛, 꽈배기 등)', '케이크류', '페이스트리류', '기타 음료 및 차류',
#        '장아찌.절임류', '적류', '어패류전', '채소류전', '부침류', '육류전', '어패류조림', '채소류조림',
#        '육류조림', '죽류', '어패류찌개.전골', '채소류찌개.전골', '육류찜', '채소류튀김', '어패류튀김',
#        '치킨류', '포류', '한과류', '리조또.그라탕류', '샐러드', '기타 튀김류', '떡볶이류', '아이스크림류',
#        '커피류', '차류', '과일.채소음료류', '탄산음료류', '스무디류', '식빵류', '빙수류', '도넛류',
#        '기타 과자류', '우유.유제품류', '주류', '쿠키.비스킷류', '스프류', '초콜릿류', '스낵류', '버거류',
#        '만두류', '기타 아이스크림류', '채소류찜', '냉국류', '기타 면 및 만두류', '기타 전.적 및 부침류',
#        '젓갈류', '기타 조림류', '기타 찜류', '기타 구이류', '곡류 및 그 제품', '감자 및 전분류', '당류',
# ...

# %%
bob = df[df['식품대분류']=='밥류']

# %%
bob
# Out:
# NO            식품명 식품대분류   식품상세분류 1회제공량 내용량_단위   에너지(㎉)    수분(g)   단백질(g)  \
# 111   고추장불고기 삼각김밥    밥류  김밥(초밥)류   100      g  165.289   59.514    3.661
# 112        곤드레나물밥    밥류    기타 밥류   350      g   521.83    230.4     10.3
# 113            국밥    밥류    기타 밥류   800      g   418.35      699     27.6
# 114          농어초밥    밥류  김밥(초밥)류   250      g  396.743  148.991   17.433
# 115          돼지국밥    밥류    기타 밥류  1200      g    911.4   1016.1     66.4
# ...           ...   ...      ...   ...    ...      ...      ...      ...
# 6539          현미밥    밥류  쌀밥.잡곡밥류   230      g      396    131.6      7.1
# 6540          흑미밥    밥류  쌀밥.잡곡밥류   200      g      348    112.7      6.5
# 6908        채소 초밥    밥류  김밥(초밥)류   280      g   393.26        -     7.59
# 6925        새우필라프    밥류     볶음밥류   253      g      438        -   9.7152
# 6926       불고기필라프    밥류     볶음밥류   259      g      465        -  11.4219
#
# NO     지방(g)  탄수화물(g)  ...     인(㎎)   칼륨(㎎)     나트륨(㎎) 아연(㎎) 비타민 B1(㎎)  \
# ...

# %%
df[df['식품상세분류'].str.contains('치킨')]
# Out:
# NO              식품명 식품대분류 식품상세분류 1회제공량 내용량_단위   에너지(㎉)   수분(g)  단백질(g)  \
# 281            양념치킨   튀김류    치킨류   200      g      552    92.1    35.5
# 284            치킨까스   튀김류    치킨류   200      g  592.998  90.939  27.913
# 474   슈퍼곡물 치킨(10조각)   튀김류    치킨류   105      g      650       -      17
# 476        치킨퐁듀 그라탕   튀김류    치킨류   176      g      370       -      36
# 477      퀴노아 치킨 샐러드   튀김류    치킨류   358      g      827       -      32
# ...             ...   ...    ...   ...    ...      ...     ...     ...
# 7582    후라이드치킨 (순살)   튀김류    치킨류   100      g        -       -      20
# 7583      양념치킨 (뼈닭)   튀김류    치킨류   100      g        -       -      17
# 7584      양념치킨 (순살)   튀김류    치킨류   100      g        -       -      12
# 7585      간장치킨 (뼈닭)   튀김류    치킨류   100      g        -       -      20
# 7586      간장치킨 (순살)   튀김류    치킨류   100      g        -       -      17
#
# NO     지방(g) 탄수화물(g) 총당류(g) 총 식이섬유(g)   나트륨(㎎) 아연(㎎) 비타민 B1(㎎) 비타민 B2(㎎)  \
# ...

# %%
df[df['식품상세분류'].str.contains('피자')]
# Out:
# NO                           식품명 식품대분류 식품상세분류 1회제공량 내용량_단위 에너지(㎉)  수분(g)  \
# 166                        불고기피자    빵류    피자류   200      g    505   90.6
# 172                         치즈피자    빵류    피자류   200      g    553     77
# 174                       페퍼로니피자    빵류    피자류   200      g    532   81.1
# 175                       포테이토피자    빵류    피자류   250      g    628  120.1
# 292              글램핑 바비큐(오리지널 L)    빵류    피자류   157      g    410      -
# ...                          ...   ...    ...   ...    ...    ...    ...
# 31338               떠먹는 컵피자 포테이토    빵류     피자   150      g    380      -
# 31732                 고메그릴피자 불고기    빵류     피자   360      g    928      -
# 31733     양송이 피자(MUSHROOM PIZZA)    빵류     피자   365      g    830      -
# 31734  4치즈 피자(FOUR CHEESE PIZZA)    빵류     피자   340      g    890      -
# 31739              오뚜기 고르곤졸라 씬피자    빵류     피자   150      g    455      -
#
# NO    단백질(g) 지방(g) 탄수화물(g) 총당류(g) 총 식이섬유(g)  나트륨(㎎) 아연(㎎) 비타민 B1(㎎) 비타민 B2(㎎)  \
# ...

# %%
df[df['식품상세분류'].str.contains('육류구이')]
# Out:
# NO                 식품명 식품대분류 식품상세분류 1회제공량 내용량_단위   에너지(㎉)    수분(g)  단백질(g)  \
# 1                 꿩불고기   구이류   육류구이   500      g    368.8    412.6    33.5
# 2                  닭갈비   구이류   육류구이   400      g   595.61    276.4    45.9
# 3                  닭갈비   구이류   육류구이   300      g   558.47    195.4    45.5
# 4                  닭꼬치   구이류   육류구이    70      g  176.723   35.308  11.562
# 7                 돼지갈비   구이류   육류구이   100      g   240.32     56.3    19.5
# 9                  불고기   구이류   육류구이   150      g   395.29     80.1    34.4
# 11             소양념갈비구이   구이류   육류구이   300      g   989.15      137    60.1
# 12               양념왕갈비   구이류   육류구이   150      g   480.81     71.8    27.1
# 16             햄버그스테이크   구이류   육류구이   200      g  457.697  118.817  26.959
# 18                훈제오리   구이류   육류구이   250      g   797.14  126.473  43.058
# 793              바비큐폭립   구이류   육류구이   428      g     1421        -      94
# ...

# %%
df[df['식품상세분류'].str.contains('탕')]
# Out:
# NO                식품명   식품대분류     식품상세분류 1회제공량 내용량_단위   에너지(㎉)    수분(g)  \
# 19                게국지  국 및 탕류     어패류국.탕  1100      g   415.25    994.8
# 20                곰치국  국 및 탕류     어패류국.탕  1000      g   419.29      895
# 21                굴국밥  국 및 탕류     어패류국.탕   650      g      683    494.6
# 22                김치국  국 및 탕류     채소류국.탕   450      g       89    425.8
# 23               떡만둣국  국 및 탕류  기타 국 및 탕류   700      g  624.915  551.861
# ...               ...     ...        ...   ...    ...      ...      ...
# 38511         우육탕큰사발면     유탕면        유탕면   115    NaN      520        -
# 38512         새우탕큰사발면     유탕면        유탕면   115    NaN      500        -
# 38513         굴진짬뽕 용기     유탕면        유탕면   110    NaN      455        -
# 38514        참치마요큰사발면     유탕면        유탕면   119    NaN      530        -
# 38525  삼육 우리밀로만든감자라면컵     유탕면        유탕면    73    NaN      325        -
#
# NO     단백질(g)   지방(g)  탄수화물(g) 총당류(g) 총 식이섬유(g)   나트륨(㎎)  아연(㎎) 비타민 B1(㎎)  \
# ...

# %%
df[df['식품대분류'].str.contains('과자')]
df[df['식품대분류'].str.contains('캔디')]
# Out:
# NO               식품명 식품대분류 식품상세분류 1회제공량 내용량_단위 에너지(㎉) 수분(g) 단백질(g) 지방(g)  \
# 12369          종합 제리   캔디류     젤리    12      g     40     -      -     -
# 12370          종합 캔디   캔디류     사탕    10      g     40     -      -     -
# 12371        블루베리 캔디   캔디류     사탕    10      g     40     -      -     -
# 12372        누룽지맛 캔디   캔디류     사탕     8      g     27     -      -     -
# 12373         땅콩 카라멜   캔디류    캐러멜    12      g     50     -      -     -
# ...              ...   ...    ...   ...    ...    ...   ...    ...   ...
# 52936       라임모히또 젤리   캔디류    캔디류    70      g    264     -      5     0
# 52937       꼬마쮸 복숭아맛   캔디류    캔디류    40      g    175     -      0   3.6
# 52938       올리렉스 로젠지   캔디류    캔디류   120      g    300     -      0     0
# 52939         블루베리캔디   캔디류    캔디류   100      g    390     -      0     0
# 52940  It's 무설탕 레몬캔디   캔디류    캔디류    40      g    100     -      0     0
#
# NO    탄수화물(g) 총당류(g) 총 식이섬유(g) 나트륨(㎎) 아연(㎎) 비타민 B1(㎎) 비타민 B2(㎎) 비타민 B12(㎍)  \
# ...

# %%
boon = df['식품대분류'].unique()

# %%
boon = pd.DataFrame(boon)

# %%
n = ['기타',  '곡류 및 서류', '포류', '과자류',
       '아이스크림류', '젓갈류', '과자', '과/채주스', '탄산음료', '과/채음료',
       '인삼/홍삼음료', '혼합음료', '음료베이스', '건면', '생면', '기타발효음료', '가공두유', '유산균음료',
       '캔디류', '환자용 식품', '숙면', '커피', '유탕면', '초콜릿가공품',
       '빙과', '탄산수', '추잉껌', '프레스햄', '만두피', '발효소시지', '농후발효유',
       '가공유', '강화우유', '가공치즈', '만두', '분쇄가공육제품', '액상차',
       '참기름', '콩기름(대두유)', '기타식물성유지', '고형차', '잼', '영/유아용 이유식',
       '소스', '곡류가공품', '마요네즈', '카레(커리)', '가공버터', '밀크초콜릿', '어육소시지', '초콜릿',
       '두부', '복합조미식품', '가공두부', '기타 수산물가공품', '자연치즈', '들기름', '발효유', '우유',
       '향미유', '당절임', '두류가공품', '떡류', '물엿', '서류가공품', '준초콜릿', '체중조절용 조제식품',
       '아이스크림', '알가열제품', '아이스밀크', '설탕', '기타설탕', '해바라기유', '올리브유', '어묵',
       '묵류', '토마토케첩', '기타 어육가공품', '조미김', '올리고당', '채종유(유채유 또는 카놀라유)',
       '밀가루', '야자유', '과실주', '당류가공품', '샤베트', '시리얼류', '땅콩 또는 견과류가공품', '벌꿀',
       '기타 코코아가공품', '김치', '과/채가공품', '절임식품', '기타 농산가공품', '신선편의식품', '베이컨류',
       '식육함유가공품', '알함유가공품', '양념젓갈', '젓갈', '조미건어포', '미강유(현미유)', '고추씨기름',
       '옥수수기름(옥배유)', '마가린', '성장기용 조제유', '영/유아용 특수조제식품', '식물성크림', '침출차',
       '혼합간장', '양조간장', '고추장', '된장', '농축과/채즙(또는 과/채분)', '발효식초', '성장기용 조제식',
       '영아용 조제유', '유당분해우유', '전지분유', '탈지분유', '버터', '가공연유', '혼합식용유', '가공유지',
       '임산/수유부용 식품', '선천성 대사질환자용 식품', '원액두유', '식용돈지', '혼합장', '비유지방아이스크림',
       '화이트초콜릿', '기타장류', '춘장', '산분해간장', '쇼트닝', '혼합분유', '개량메주', '가공유크림',
       '크림발효유', '농후크림발효유', '생햄', '혼합소시지', '저지방아이스크림', '기타잼', '영아용 조제식',
       '산양유', '추출가공식품', '탈지농축우유', '올리고당가공품', '고춧가루', '전분가공품', '유산균첨가우유']

# %%
pd.DataFrame(n)
# Out:
#            0
# 0         기타
# 1    곡류 및 서류
# 2         포류
# 3        과자류
# 4     아이스크림류
# ..       ...
# 147   탈지농축우유
# 148  올리고당가공품
# 149     고춧가루
# 150    전분가공품
# 151  유산균첨가우유
#
# [152 rows x 1 columns]

# %%
drop_row = []
for i in n:
    add_row = df[df['식품대분류'] == i].index
    drop_row.append(add_row)

# %%
drop_row
# Out:
# [Index([  44,  104,  482,  585,  586,  587,  788,  814,  815,  816,  890, 1028,
#         1036, 1037, 1038, 1039, 1172, 1173, 1209, 1223, 1224, 1225, 1447, 1448,
#         2366, 2581, 2582, 3051, 3052, 3053, 3054, 3527, 3528, 3529, 3530, 3531,
#         3532, 3533, 3534, 3535, 3536, 3878, 3879, 3880, 3881, 4253, 4254, 4904,
#         5386, 5387, 5388, 5389, 5390, 5391, 5392, 5393, 5394, 5395, 5420, 5421,
#         5422, 5423, 5489, 5490, 5491, 5492, 5493, 5497, 5498, 5499, 5500, 5501,
#         5502, 5776, 5777, 5891, 5892, 5945, 6430, 6436, 6461, 6462, 6542, 6963],
#        dtype='object'),
#  Index([  57,   58,   59,   60,   61,   62,   63,   64,   65,   66,   67,   68,
#           69,   70, 5399, 5400, 6786, 6787, 6788, 6789, 6790, 6791, 6792, 6793,
#         6794, 6798, 6799, 6800, 7372],
#        dtype='object'),
#  Index([285, 286], dtype='object'),
#  Index([ 287,  288,  289,  290,  291, 1208, 1210, 1211, 1212, 1213,
#         ...
# ...

# %%
for i in drop_row:
    df.drop(i,inplace=True)

# %%
df
# Out:
# NO             식품명 식품대분류 식품상세분류 1회제공량 내용량_단위   에너지(㎉)   수분(g)  단백질(g)  지방(g)  \
# 1             꿩불고기   구이류   육류구이   500      g    368.8   412.6    33.5    8.5
# 2              닭갈비   구이류   육류구이   400      g   595.61   276.4    45.9   25.8
# 3              닭갈비   구이류   육류구이   300      g   558.47   195.4    45.5   31.6
# 4              닭꼬치   구이류   육류구이    70      g  176.723  35.308  11.562  8.565
# 5             더덕구이   구이류  채소류구이   100      g      184    58.1     3.1    5.2
# ...            ...   ...    ...   ...    ...      ...     ...     ...    ...
# 47903   구운감자치즈포카치아    빵류     빵류   135      g      378       -      14     18
# 47904  베리베리크림치즈베이글    빵류     빵류   162      g      470       -      11     22
# 47905        호두앙금빵    빵류     빵류   155      g      416       -      10      8
# 47906         콘브레드    빵류     빵류   126      g      469       -      10     25
# 47907  [AOP]정통크로와상    빵류     빵류    45      g      216       -       3     16
#
# ...

# %%
df = df[df["식품대분류"]!='빵류']
df = df.reset_index(drop=True)

# %%
df
# Out:
# NO                식품명   식품대분류  식품상세분류 1회제공량 내용량_단위   에너지(㎉)   수분(g)  단백질(g)  \
# 0                꿩불고기     구이류    육류구이   500      g    368.8   412.6    33.5
# 1                 닭갈비     구이류    육류구이   400      g   595.61   276.4    45.9
# 2                 닭갈비     구이류    육류구이   300      g   558.47   195.4    45.5
# 3                 닭꼬치     구이류    육류구이    70      g  176.723  35.308  11.562
# 4                더덕구이     구이류   채소류구이   100      g      184    58.1     3.1
# ...               ...     ...     ...   ...    ...      ...     ...     ...
# 15471       요거트 영양 컵죽  즉석조리식품  즉석조리식품    40    NaN      164       -     1.6
# 15472  영양반찬 고구마단호박그라탕  즉석조리식품  즉석조리식품   130    NaN      178       -       4
# 15473     영양반찬 감자야채볶음  즉석조리식품  즉석조리식품   130    NaN       90       -     2.4
# 15474     영양반찬 감자멸치조림  즉석조리식품  즉석조리식품   130    NaN      100       -       6
# 15475      남양키플러스고소한맛  즉석섭취식품  즉석섭취식품    39    NaN      155       -       6
#
# ...

# %%
df.to_excel("식단예시.xlsx", encoding="utf-8-sig")

# %%
df.drop(df[df['에너지(㎉)']=='-'].index,inplace=True)
df = df.reset_index(drop=True)

# %%
df.drop(df[df['단백질(g)']=='-'].index,inplace=True)
df = df.reset_index(drop=True)

# %%
df.drop(df[df['지방(g)']=='-'].index,inplace=True)
df.drop(df[df['탄수화물(g)']=='-'].index,inplace=True)
df = df.reset_index(drop=True)

# %%
df.drop(df[df['총당류(g)']=='-'].index,inplace=True)
df.drop(df[df['총 식이섬유(g)']=='-'].index,inplace=True)
df.drop(df[df['나트륨(㎎)']=='-'].index,inplace=True)
df.drop(df[df['콜레스테롤(㎎)']=='-'].index,inplace=True)
df.drop(df[df['총 포화 지방산(g)']=='-'].index,inplace=True)
df = df.reset_index(drop=True)

# %%
df.drop(df[df['식품대분류']=='음료 및 차류'].index,inplace=True)
df = df.reset_index(drop=True)

# %%
df['단백질(g)'] = df['단백질(g)'].astype(float)
df['지방(g)'] = df['지방(g)'].astype(float)
df['탄수화물(g)'] = df['탄수화물(g)'].astype(float)
df['총당류(g)'] = df['총당류(g)'].astype(float)
df['총 식이섬유(g)'] = df['총 식이섬유(g)'].astype(float)
df['나트륨(㎎)'] = df['나트륨(㎎)'].astype(float)
df['콜레스테롤(㎎)'] = df['콜레스테롤(㎎)'].astype(float)
df['총 포화 지방산(g)'] = df['총 포화 지방산(g)'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1452/1089169476.py in <module>
#       2 df['지방(g)'] = df['지방(g)'].astype(float)
#       3 df['탄수화물(g)'] = df['탄수화물(g)'].astype(float)
# ----> 4 df['총당류(g)'] = df['총당류(g)'].astype(float)
#       5 df['총 식이섬유(g)'] = df['총 식이섬유(g)'].astype(float)
#       6 df['나트륨(㎎)'] = df['나트륨(㎎)'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5918         else:
#    5919             # else, only a single dtype is given
# -> 5920             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5921             return self._constructor(new_data).__finalize__(self, method="astype")
#    5922
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
# ...

# %%
df
# Out:
# NO                             식품명   식품대분류  식품상세분류 1회제공량 내용량_단위   에너지(㎉)  \
# 0                             꿩불고기     구이류    육류구이   500      g  368.800
# 1                              닭갈비     구이류    육류구이   400      g  595.610
# 2                              닭갈비     구이류    육류구이   300      g  558.470
# 3                              닭꼬치     구이류    육류구이    70      g  176.723
# 4                             더덕구이     구이류   채소류구이   100      g  184.000
# ...                            ...     ...     ...   ...    ...      ...
# 3968  고슬고슬 계란코팅 황금밥알200℃ 새우&갈릭 볶음밥  즉석조리식품  즉석조리식품   210    NaN  425.000
# 3969                   프리미엄 웰선식 사과  즉석섭취식품  즉석섭취식품    50    NaN  206.000
# 3970                   프리미엄 웰선식 딸기  즉석섭취식품  즉석섭취식품    50    NaN  199.000
# 3971                   단백한끼 달달한카카오  즉석섭취식품  즉석섭취식품    25    NaN   90.000
# 3972           키토선생 베이컨칠리오믈렛&컬리라이스  즉석조리식품  즉석조리식품   350    NaN  491.000
#
# NO     수분(g)  단백질(g)   지방(g)  탄수화물(g) 총당류(g) 총 식이섬유(g)   나트륨(㎎) 아연(㎎)  \
# ...

# %%
df['에너지(㎉)'] = df['에너지(㎉)'].astype(float)

# %%
df[df['에너지(㎉)']>500]
# Out:
# NO                      식품명   식품대분류  식품상세분류 1회제공량 내용량_단위  에너지(㎉)    수분(g)  \
# 1                       닭갈비     구이류    육류구이   400      g  595.61    276.4
# 2                       닭갈비     구이류    육류구이   300      g  558.47    195.4
# 10                  소양념갈비구이     구이류    육류구이   300      g  989.15      137
# 17                     훈제오리     구이류    육류구이   250      g  797.14  126.473
# 20                      굴국밥  국 및 탕류  어패류국.탕   650      g  683.00    494.6
# ...                     ...     ...     ...   ...    ...     ...      ...
# 14511             버섯소불고기도시락  즉석조리식품  즉석조리식품   357    NaN  629.00        -
# 14518             고추장불고기도시락  즉석조리식품  즉석조리식품   351    NaN  620.00        -
# 14522              코다리조림도시락  즉석조리식품  즉석조리식품   353    NaN  558.00        -
# 14541          그릴함박 & 철판볶음밥  즉석조리식품  즉석조리식품   275    NaN  535.00        -
# 14547  키토선생 크림소스 갈릭치킨&컬리라이스  즉석조리식품  즉석조리식품   350    NaN  542.00        -
#
# NO     단백질(g)   지방(g) 탄수화물(g) 총당류(g) 총 식이섬유(g)    나트륨(㎎)  아연(㎎) 비타민 B1(㎎)  \
# ...

# %%
df[df['에너지(㎉)']<200]
# Out:
# NO                식품명   식품대분류  식품상세분류 1회제공량 내용량_단위   에너지(㎉)   수분(g)  단백질(g)  \
# 3                 닭꼬치     구이류    육류구이    70      g  176.723  35.308  11.562
# 4                더덕구이     구이류   채소류구이   100      g  184.000    58.1     3.1
# 21                김치국  국 및 탕류  채소류국.탕   450      g   89.000   425.8     5.4
# 25               매생이국  국 및 탕류  어패류국.탕   500      g  119.000   468.8      10
# 26               무된장국  국 및 탕류  채소류국.탕   450      g  104.000     421     6.1
# ...               ...     ...     ...   ...    ...      ...     ...     ...
# 14589       요거트 영양 컵죽  즉석조리식품  즉석조리식품    40    NaN  164.000       -     1.6
# 14590  영양반찬 고구마단호박그라탕  즉석조리식품  즉석조리식품   130    NaN  178.000       -       4
# 14591     영양반찬 감자야채볶음  즉석조리식품  즉석조리식품   130    NaN   90.000       -     2.4
# 14592     영양반찬 감자멸치조림  즉석조리식품  즉석조리식품   130    NaN  100.000       -       6
# 14593      남양키플러스고소한맛  즉석섭취식품  즉석섭취식품    39    NaN  155.000       -       6
#
# ...

# %%
df
# Out:
# NO      식품명 식품대분류 식품상세분류 1회제공량 내용량_단위   에너지(㎉)   수분(g)  단백질(g)   지방(g)  \
# 0      꿩불고기   구이류   육류구이   500      g  368.800   412.6  33.500   8.500
# 1       닭갈비   구이류   육류구이   400      g  595.610   276.4  45.900  25.800
# 2       닭갈비   구이류   육류구이   300      g  558.470   195.4  45.500  31.600
# 3       닭꼬치   구이류   육류구이    70      g  176.723  35.308  11.562   8.565
# 4      더덕구이   구이류  채소류구이   100      g  184.000    58.1   3.100   5.200
# ..      ...   ...    ...   ...    ...      ...     ...     ...     ...
# 740   오징어튀김   튀김류  어패류튀김   150      g  505.000    62.8  18.600  33.000
# 741    채소튀김   튀김류  채소류튀김   100      g  404.000    31.3   3.300  27.100
# 742    치킨너겟   튀김류    치킨류   150      g  468.000    74.3  22.500  35.400
# 743     탕수육   튀김류   육류튀김   200      g  358.000   127.8  27.200  16.800
# 744  후라이드치킨   튀김류    치킨류   200      g  530.000   107.1  35.500  33.700
#
# NO   탄수화물(g) 총당류(g) 총 식이섬유(g)   나트륨(㎎)    아연(㎎) 비타민 B1(㎎) 비타민 B2(㎎)  \
# ...

# %%
df.drop(df[df['식품대분류']=='즉석조리식품'].index,inplace=True)
df = df.reset_index(drop=True)

# %%
df.drop(df[df['식품대분류']=='즉석섭취식품'].index,inplace=True)
df = df.reset_index(drop=True)

# %%
df.drop(df[df['식품대분류']=='농축산물'].index,inplace=True)
df = df.reset_index(drop=True)
