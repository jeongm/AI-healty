# %%
import pandas as pd

# %%
Nutr = pd.read_excel("통합 식품영양성분DB_필요성분추출.xlsx",index_col='Unnamed: 0')

# %%
Nutr.head()
# Out:
#                           Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 최종 DB 업데이트 일 : 2021-03-10        NaN        NaN        NaN        NaN
# NaN                              NaN        NaN        NaN        NaN
# NO                               식품명      식품대분류     식품상세분류      1회제공량
# 1                               꿩불고기        구이류       육류구이        500
# 2                                닭갈비        구이류       육류구이        400
#
#                           Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 최종 DB 업데이트 일 : 2021-03-10        NaN        NaN        NaN        NaN
# NaN                              NaN        NaN        NaN        NaN
# NO                            내용량_단위    총내용량(g)     에너지(㎉)      수분(g)
# 1                                  g          -      368.8      412.6
# 2                                  g          -     595.61      276.4
#
#                           Unnamed: 9 Unnamed: 10  ...     Unnamed: 59  \
# ...

# %%
Nutr.columns = Nutr.iloc[2]

# %%
Nutr = Nutr[3:]

# %%
Nutr.head()
# Out:
# NO   식품명 식품대분류 식품상세분류 1회제공량 내용량_단위 총내용량(g)   에너지(㎉)   수분(g)  단백질(g)  지방(g)  \
# 1   꿩불고기   구이류   육류구이   500      g       -    368.8   412.6    33.5    8.5
# 2    닭갈비   구이류   육류구이   400      g       -   595.61   276.4    45.9   25.8
# 3    닭갈비   구이류   육류구이   300      g       -   558.47   195.4    45.5   31.6
# 4    닭꼬치   구이류   육류구이    70      g       -  176.723  35.308  11.562  8.565
# 5   더덕구이   구이류  채소류구이   100      g       -      184    58.1     3.1    5.2
#
# NO  ... 총 단일 불포화지방산(g) 총 단일 불포화지방산(%) 총 다중 불포화지방산(g) 총 다중 불포화지방산(%)  \
# 1   ...              -              -              -              -
# 2   ...              -              -              -              -
# 3   ...              -              -              -              -
# 4   ...              -              -              -              -
# 5   ...              -              -              -              -
#
# NO 오메가 3 지방산(g) 오메가 6 지방산(g) 트랜스 지방산(g) 총 불포화지방산(g)  회분(g) 카페인(㎎)
# ...

# %%
menu = pd.read_excel("메뉴분할본.xlsx",index_col='Unnamed: 0')

# %%
menu.head()
# Out:
#                     1          2        3      4    5
# 0  해운대31cm해물칼국수 창원해운점  31cm해물칼국수   8,500원  해물칼국수  NaN
# 1  해운대31cm해물칼국수 창원해운점  31cm 해물파전  10,000원   해물파전  NaN
# 2  해운대31cm해물칼국수 창원해운점    조개전골(대)  39,000원   조개전골  NaN
# 3       마실밥상 창원마산합포구점        특선A  15,000원    NaN  NaN
# 4       마실밥상 창원마산합포구점        특선B  19,000원    NaN  NaN

# %%
menu_name = menu[4].dropna()

# %%
menu_name = menu_name.reset_index(drop=True)

# %%
menu_name = menu_name.drop_duplicates().reset_index(drop=True)

# %%
menu_name
# Out:
# 0       해물칼국수
# 1        해물파전
# 2        조개전골
# 3          초밥
# 4        쟁반짜장
#         ...
# 302     계란후라이
# 303    고구마돈까스
# 304      비빔만두
# 305       어묵탕
# 306      모밀국수
# Name: 4, Length: 307, dtype: object

# %%
Nutr[Nutr['식품명'] == '꿩불고기']
# Out:
# NO   식품명 식품대분류 식품상세분류 1회제공량 내용량_단위 총내용량(g) 에너지(㎉)  수분(g) 단백질(g) 지방(g)  ...  \
# 1   꿩불고기   구이류   육류구이   500      g       -  368.8  412.6   33.5   8.5  ...
#
# NO 총 단일 불포화지방산(g) 총 단일 불포화지방산(%) 총 다중 불포화지방산(g) 총 다중 불포화지방산(%) 오메가 3 지방산(g)  \
# 1               -              -              -              -            -
#
# NO 오메가 6 지방산(g) 트랜스 지방산(g) 총 불포화지방산(g) 회분(g) 카페인(㎎)
# 1             -        0.1           -   5.8      -
#
# [1 rows x 68 columns]

# %%
Nutr[Nutr['식품명'] == ''].values
# Out:
# array([], shape=(0, 68), dtype=object)

# %%
(Nutr[Nutr['식품명'] == ''].values) != (Nutr[Nutr['식품명'] == '꿩불고기'].values)
# Out:
# array([], shape=(0, 68), dtype=bool)

# %%
menu_name.values
# Out:
# array(['해물칼국수', '해물파전', '조개전골', '초밥', '쟁반짜장', '야끼우동', '짜장면', '짬뽕', '우동',
#        '간짜장', '해물짬뽕', '아메리카노', '카푸치노', '카페라떼', '바닐라라떼', '카페모카', '레몬에이드',
#        '삼겹살', '우삼겹', '막창', '꽃등심', '육회', '생삼겹', '소고기국밥', '차돌박이', '생목살',
#        '사골곰탕', '소전골', '된장찌개', '낙지볶음탕', '등심스테이크', '로제파스타', '리조또', '치킨스테이크',
#        '쿠키', '제육볶음', '수육', '고등어조림', '족발', '곱창전골', '선짓국', '삽겹살', '목살',
#        '갈빗살', '새우살', '물냉면', '에스프레소', '자몽쥬스', '오렌지주스', '자몽에이드', '회', '향어회',
#        '매운탕', '연어초밥', '나가사끼우동', '연어샐러드', '새우튀김', '연어회', '규동', '가라아게동',
#        '가츠동', '에비동', '공기밥', '소고기샐러드', '치킨샐러드', '교자만두', '타코야끼', '고로케',
#        '코카콜라', '환타', '스프라이트', '카스', '진로', '사케', '테라', '화이트', '하이볼',
#        '닭가슴살샐러드', '크림파스타', '오일파스타', '살치살스테이크', '모닝빵', '필라프', '갈치조림',
#        '돼지주물럭', '아귀탕', '밀크티', '스콘', '순두부찌개', '청국장', '김치찌개', '육개장',
#        '돼지두루치기', '굴국밥', '까르보나라파스타', '봉골레파스타', '스파게티', '빠네스파게티', '크림리조또',
#        '산낙지볶음', '불고기', '산낙지', '낙지탕탕이', '낙지전골', '돈까스', '국물떡볶이', '로제떡볶이',
# ...

# %%
class_name = pd.DataFrame()
for i in menu_name.values:
    class_name = pd.concat([class_name,Nutr[Nutr['식품명'] == i]])

# %%
class_name
# Out:
# NO        식품명      식품대분류    식품상세분류 1회제공량 내용량_단위 총내용량(g)   에너지(㎉)    수분(g)  \
# 96      해물칼국수    면 및 만두류       국수류   900      g       -  628.262  741.007
# 7203     해물파전  전.적 및 부침류      어패류전   150      g       -      256      100
# 13554    야끼우동         생면        생면   239      g       -      405        -
# 6966      짜장면    면 및 만두류      중식면류   600      g       -      529    478.5
# 10588     짜장면       농축산물    조리가공품류   100      g       -      122     72.2
# ...       ...        ...       ...   ...    ...     ...      ...      ...
# 32879   새우볶음밥     즉석조리식품    즉석조리식품   160      g     160    260.7        -
# 36622   새우볶음밥     즉석조리식품    즉석조리식품   250      g     250      430        -
# 37007   새우볶음밥     즉석조리식품    즉석조리식품   160      g     160      242        -
# 37585   새우볶음밥     즉석조리식품    즉석조리식품   230      g     230      365        -
# 7286   참치김치찌개   찌개 및 전골류  어패류찌개.전골   300      g       -      154    268.1
#
# NO     단백질(g)  지방(g)  ... 총 단일 불포화지방산(g) 총 단일 불포화지방산(%) 총 다중 불포화지방산(g)  \
# ...

# %%
class_name = class_name.drop_duplicates(['식품명']).reset_index(drop=True)

# %%
class_name.to_excel('주변음식점.xlsx', encoding='utf-8-sig')

# %%
class_name['식품명']
# Out:
# 0       해물칼국수
# 1        해물파전
# 2        야끼우동
# 3         짜장면
# 4          짬뽕
#         ...
# 144       대구찜
# 145        멍게
# 146      닭볶음탕
# 147     새우볶음밥
# 148    참치김치찌개
# Name: 식품명, Length: 149, dtype: object

# %%
menu_name
# Out:
# 0       해물칼국수
# 1        해물파전
# 2        조개전골
# 3          초밥
# 4        쟁반짜장
#         ...
# 302     계란후라이
# 303    고구마돈까스
# 304      비빔만두
# 305       어묵탕
# 306      모밀국수
# Name: 4, Length: 307, dtype: object
