# %%
import pandas as pd

# %%
df1 = pd.read_csv("1차음식점.csv")
df2 = pd.read_csv("2차음식점.csv")
df3 = pd.read_csv("3차음식점.csv")
df4 = pd.read_csv("4차음식점.csv")
df5 = pd.read_csv("5차음식점.csv")
df6 = pd.read_csv("6차음식점.csv")

# %%
df1
# Out:
#             Unnamed: 0                                                  0  \
# 0   해운대31cm해물칼국수 창원해운점  31cm해물칼국수\n31cm해물칼국수\n동죽,가리비,홍합과 어우러진 칼국수 입니다\...
# 1        마실밥상 창원마산합포구점                  특선A\n특선A\n점심특선A 수제떠칼비 1개\n15,000원
# 2                  스시혼  스시혼정식코스\n스시혼정식코스\n대표\n샐러드+사시미+초밥8pcs+튀김+우동or냉모...
# 3                   금향  쟁반짜장\n대표\n2인분 19,000원 매콤한맛(기본), 순한맛 선택 가능\n10,...
# 4              몬스터로스터스                             이미지 준비중\n아메리카노\n3,800원
# 5             고기한판 1호점  고기한판\n고기한판\n초벌삼겹살+목살+항정살+대패삼겹살+한판볶음밥+한판국수\n13,...
# 6               하동식육식당                          한우특수부위(200g)\n대표\n36,000원
# 7                 오또브레                이미지 준비중\n이베리코 뼈등심 스테이크\n대표\n21,800원
# 8                 존스커피  수제쿠키\n수제쿠키\n유기농밀로 빚은 6가지 종류의 수제쿠키. 깔끔하고 담백한 후미...
# 9            큰집게장정식 본점                                                NaN
# 10            텐동하나 마산점                                                NaN
# 11                  다채                             제육쌈밥정식\n제육쌈밥정식\n9,000원
# ...

# %%
df = pd.concat([df1,df2])

# %%
df
# Out:
#             Unnamed: 0                                                  0  \
# 0   해운대31cm해물칼국수 창원해운점  31cm해물칼국수\n31cm해물칼국수\n동죽,가리비,홍합과 어우러진 칼국수 입니다\...
# 1        마실밥상 창원마산합포구점                  특선A\n특선A\n점심특선A 수제떠칼비 1개\n15,000원
# 2                  스시혼  스시혼정식코스\n스시혼정식코스\n대표\n샐러드+사시미+초밥8pcs+튀김+우동or냉모...
# 3                   금향  쟁반짜장\n대표\n2인분 19,000원 매콤한맛(기본), 순한맛 선택 가능\n10,...
# 4              몬스터로스터스                             이미지 준비중\n아메리카노\n3,800원
# ..                 ...                                                ...
# 31               맷돌콩국수                                 콩국수(4~10월)\n7,000원
# 32        본세이로무시 마산직영점                                                NaN
# 33       충무로38양곱창 신마산점                                                NaN
# 34              52 돈까스                                    미트소스돈까스\n9,000원
# 35            교촌치킨 월영점                                                NaN
#
#                                             1  \
# ...

# %%
df = pd.concat([df,df3])
df = pd.concat([df,df4])
df = pd.concat([df,df5])
df = pd.concat([df,df6])

# %%
df.rename(columns={'Unnamed: 0':'식당이름'},inplace=True)

# %%
df.drop_duplicates(['식당이름'],inplace=True)

# %%
df
# Out:
#                   식당이름                                                  0  \
# 0   해운대31cm해물칼국수 창원해운점  31cm해물칼국수\n31cm해물칼국수\n동죽,가리비,홍합과 어우러진 칼국수 입니다\...
# 1        마실밥상 창원마산합포구점                  특선A\n특선A\n점심특선A 수제떠칼비 1개\n15,000원
# 2                  스시혼  스시혼정식코스\n스시혼정식코스\n대표\n샐러드+사시미+초밥8pcs+튀김+우동or냉모...
# 3                   금향  쟁반짜장\n대표\n2인분 19,000원 매콤한맛(기본), 순한맛 선택 가능\n10,...
# 4              몬스터로스터스                             이미지 준비중\n아메리카노\n3,800원
# ..                 ...                                                ...
# 62                김박곱창                                                NaN
# 63              원탁가라오케                                     맥주\n맥주\n5,000원
# 64           맥도날드 신마산점  빅맥® 세트\n빅맥® 세트\n100% 순 쇠고기 패티 두 장에 빅맥®만의 특별한 소...
# 65            청년피자 합포점                                                NaN
# 66           달곰김밥 경남대점                                                김밥류
#
#                                                     1  \
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.to_excel("음식점최종본.xlsx",encoding='utf-8-sig')

# %%
df = pd.read_excel("음식점데이터수집최종.xlsx",index_col='Unnamed: 0')

# %%
df.iloc[9].dropna()
# Out:
# 식당이름                        큰집게장정식 본점
# 4               돌게장 정식\n12,000원\n주문하기
# 5             양념 꽃게 정식\n12,000원\n주문하기
# 6       꽃게장 정식 (암꽃게1미)\n25,000원\n주문하기
# 7               새우장 정식\n11,000원\n주문하기
# 8               해물찜(소)\n35,000원\n주문하기
# 9               해물찜(대)\n45,000원\n주문하기
# 11                               고객센터
# 12                               이용약관
# Name: 9, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 0 to 156
# Columns: 110 entries, 식당이름 to 108
# dtypes: object(110)
# memory usage: 136.1+ KB

# %%
df.iloc[0].dropna()
# Out:
# 식당이름                                   해운대31cm해물칼국수 창원해운점
# 0       31cm해물칼국수\n31cm해물칼국수\n동죽,가리비,홍합과 어우러진 칼국수 입니다\...
# 1                             이미지 준비중\n31cm 해물파전\n10,000원
# 2                               이미지 준비중\n조개전골(대)\n39,000원
# Name: 0, dtype: object

# %%
nandf = pd.DataFrame()

# %%
for i in range(157):
    nandf = pd.concat([nandf,df.iloc[i].dropna().reset_index(drop=True)],axis=1)

# %%
nandf = nandf.T

# %%
nandf.iloc[0]
# Out:
# 0                                    해운대31cm해물칼국수 창원해운점
# 1     31cm해물칼국수\n31cm해물칼국수\n동죽,가리비,홍합과 어우러진 칼국수 입니다\...
# 2                           이미지 준비중\n31cm 해물파전\n10,000원
# 3                             이미지 준비중\n조개전골(대)\n39,000원
# 4                                                   NaN
#                             ...
# 93                                                  NaN
# 94                                                  NaN
# 95                                                  NaN
# 96                                                  NaN
# 97                                                  NaN
# Name: 0, Length: 98, dtype: object

# %%
nandf
# Out:
#                      0                                                  1   \
# 0    해운대31cm해물칼국수 창원해운점  31cm해물칼국수\n31cm해물칼국수\n동죽,가리비,홍합과 어우러진 칼국수 입니다\...
# 1         마실밥상 창원마산합포구점                  특선A\n특선A\n점심특선A 수제떠칼비 1개\n15,000원
# 2                   스시혼  스시혼정식코스\n스시혼정식코스\n대표\n샐러드+사시미+초밥8pcs+튀김+우동or냉모...
# 3                    금향  쟁반짜장\n대표\n2인분 19,000원 매콤한맛(기본), 순한맛 선택 가능\n10,...
# 4               몬스터로스터스                             이미지 준비중\n아메리카노\n3,800원
# ..                  ...                                                ...
# 152                김박곱창                             불고기한판세트\n18,000원\n주문하기
# 153              원탁가라오케                                     맥주\n맥주\n5,000원
# 154           맥도날드 신마산점  빅맥® 세트\n빅맥® 세트\n100% 순 쇠고기 패티 두 장에 빅맥®만의 특별한 소...
# 155            청년피자 합포점                           (신메뉴)토핑농장\n24,900원\n주문하기
# 156           달곰김밥 경남대점                                                김밥류
#
#                                                     2   \
# ...

# %%
nandf.to_excel("음식점nan삭제본.xlsx",encoding='utf-8-sig')

# %%
nandf.iloc[0][5] == NaN
# Out:
# False

# %%
nandf.iloc[0][1].split()
# Out:
# ['31cm해물칼국수', '31cm해물칼국수', '동죽,가리비,홍합과', '어우러진', '칼국수', '입니다', '8,500원']

# %%
nandf.iloc[0][0]
# Out:
# '해운대31cm해물칼국수 창원해운점'

# %%
li = [nandf.iloc[0][0], nandf.iloc[0][1].split()[1],nandf.iloc[0][1].split()[-1]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5884/384019066.py in <module>
# ----> 1 li = [nandf.iloc[-1][0], nandf.iloc[-1][1].split()[1],nandf.iloc[-1][1].split()[-1]]
#
# IndexError: list index out of range

# %%
rest_df = pd.DataFrame()

# %%
for i in range(157):
    for j in range(1,98):
        if type(nandf.iloc[i][j]) == type("")  and nandf.iloc[i][j].split()[-1][-1] == '원':
            if nandf.iloc[i][j].split() == 'NaN':
                break
            if nandf.iloc[i][j].split('\n')[0] == '이미지 준비중':
                rest_df = rest_df.append(pd.Series([rest_df,nandf.iloc[i][0], nandf.iloc[i][j].split('\n')[1],nandf.iloc[i][j].split('\n')[-1]])[1:],ignore_index=True)
            else:
                rest_df = rest_df.append(pd.Series([rest_df,nandf.iloc[i][0], nandf.iloc[i][j].split('\n')[0],nandf.iloc[i][j].split('\n')[-1]])[1:],ignore_index=True)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5884/1003672606.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   rest_df = rest_df.append(pd.Series([rest_df,nandf.iloc[i][0], nandf.iloc[i][j].split('\n')[0],nandf.iloc[i][j].split('\n')[-1]])[1:],ignore_index=True)
# C:\Users\User\AppData\Local\Temp/ipykernel_5884/1003672606.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   rest_df = rest_df.append(pd.Series([rest_df,nandf.iloc[i][0], nandf.iloc[i][j].split('\n')[1],nandf.iloc[i][j].split('\n')[-1]])[1:],ignore_index=True)
# C:\Users\User\AppData\Local\Temp/ipykernel_5884/1003672606.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
rest_df
# Out:
#                        1          2        3
# 0     해운대31cm해물칼국수 창원해운점  31cm해물칼국수   8,500원
# 1     해운대31cm해물칼국수 창원해운점  31cm 해물파전  10,000원
# 2     해운대31cm해물칼국수 창원해운점    조개전골(대)  39,000원
# 3          마실밥상 창원마산합포구점        특선A  15,000원
# 4          마실밥상 창원마산합포구점        특선B  19,000원
# ...                  ...        ...      ...
# 1195           달곰김밥 경남대점        물냉면   6,500원
# 1196           달곰김밥 경남대점       비빔냉면   7,000원
# 1197           달곰김밥 경남대점         콜라   2,000원
# 1198           달곰김밥 경남대점        사이다   2,000원
# 1199           달곰김밥 경남대점         환타   2,000원
#
# [1200 rows x 3 columns]

# %%
rest_df.to_excel("메뉴분할본.xlsx", encoding='utf-8-sig')
